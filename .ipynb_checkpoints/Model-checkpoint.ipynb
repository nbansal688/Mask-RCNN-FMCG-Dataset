# %%
import numpy as np
import os
import cv2
import matplotlib.pyplot as plt
import matplotlib
from mrcnn.config import Config
from mrcnn import utils
import mrcnn.model as modellib
from mrcnn import visualize
import random
import xmltodict
from mrcnn.model import log
ROOT_DIR = "./"
# Out:
# Using TensorFlow backend.

# %%
MODEL_DIR = "../model_saved"
COCO_MODEL_PATH = "../mask_rcnn_coco.h5"

# %% [markdown]
# # Visualizing Images

# %%
def get_ax(rows = 1, cols = 1, size = 8):
    """Return a Matplotlib Axes array to be used in
    all visualizations in the notebook. Provide a
    central point to control graph sizes.
    
    Change the default size attribute to control the size
    of rendered images
    """
    _, ax = plt.subplots(rows, cols, figsize = (size*cols, size*rows))
    return ax

# %% [markdown]
# # Configuration of Model

# %%
class ShapesConfig(Config):
    def __init__(self, num_classes):
        self.NUM_CLASSES = 1 + 5
        super().__init__()
    """Configuration for training.
    """
    # Give the configuration a recognizable name
    NAME = "objects"
    
    
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

    # Number of classes (including background)
    # Use small images for faster training. Set the limits of the small side
    # the large side, and that determines the image shape.
    IMAGE_MIN_DIM = 512
    IMAGE_MAX_DIM = 768
    
    DETECTION_MAX_INSTANCES = 15

    # Use smaller anchors because our image and objects are small
    RPN_ANCHOR_SCALES = (8, 16, 32, 64, 128)  # anchor side in pixels

    # Reduce training ROIs per image because the images are small and have
    # few objects. Aim to allow ROI sampling to pick 33% positive ROIs.
    TRAIN_ROIS_PER_IMAGE = 32

    # Use a small epoch since the data is simple
    STEPS_PER_EPOCH = 100

    # use small validation steps since the epoch is small
    VALIDATION_STEPS = 5
    
config = ShapesConfig(num_classes = 6)
config.display()
# Out:
# Configurations:
# BACKBONE                       resnet101
# BACKBONE_STRIDES               [4, 8, 16, 32, 64]
# BATCH_SIZE                     1
# BBOX_STD_DEV                   [0.1 0.1 0.2 0.2]
# COMPUTE_BACKBONE_SHAPE         None
# DETECTION_MAX_INSTANCES        15
# DETECTION_MIN_CONFIDENCE       0.7
# DETECTION_NMS_THRESHOLD        0.3
# FPN_CLASSIF_FC_LAYERS_SIZE     1024
# GPU_COUNT                      1
# GRADIENT_CLIP_NORM             5.0
# IMAGES_PER_GPU                 1
# IMAGE_MAX_DIM                  768
# IMAGE_META_SIZE                18
# IMAGE_MIN_DIM                  512
# IMAGE_MIN_SCALE                0
# IMAGE_RESIZE_MODE              square
# IMAGE_SHAPE                    [768 768   3]
# LEARNING_MOMENTUM              0.9
# LEARNING_RATE                  0.001
# LOSS_WEIGHTS                   {'rpn_class_loss': 1.0, 'rpn_bbox_loss': 1.0, 'mrcnn_class_loss': 1.0, 'mrcnn_bbox_loss': 1.0, 'mrcnn_mask_loss': 1.0}
# MASK_POOL_SIZE                 14
# MASK_SHAPE                     [28, 28]
# MAX_GT_INSTANCES               100
# MEAN_PIXEL                     [123.7 116.8 103.9]
# MINI_MASK_SHAPE                (56, 56)
# NAME                           objects
# NUM_CLASSES                    6
# POOL_SIZE                      7
# POST_NMS_ROIS_INFERENCE        1000
# POST_NMS_ROIS_TRAINING         2000
# ROI_POSITIVE_RATIO             0.33
# RPN_ANCHOR_RATIOS              [0.5, 1, 2]
# RPN_ANCHOR_SCALES              (8, 16, 32, 64, 128)
# RPN_ANCHOR_STRIDE              1
# RPN_BBOX_STD_DEV               [0.1 0.1 0.2 0.2]
# RPN_NMS_THRESHOLD              0.7
# RPN_TRAIN_ANCHORS_PER_IMAGE    256
# STEPS_PER_EPOCH                100
# TOP_DOWN_PYRAMID_SIZE          256
# TRAIN_BN                       False
# TRAIN_ROIS_PER_IMAGE           32
# USE_MINI_MASK                  True
# USE_RPN_ROIS                   True
# VALIDATION_STEPS               5
# WEIGHT_DECAY                   0.0001

# %% [markdown]
# # Creating Dataset

# %%
class ShapesDataset(utils.Dataset):
    """Generates the objects dataset.
    """

    def load_shapes(self , folder_name):
        """Loads all the number of images.
        """
        # Add classes
        self.add_class("objects", 1, "beauty")
        self.add_class("objects", 2, "venus")
        self.add_class("objects", 3, "pharmacy")
        self.add_class("objects" , 4 , "oralcare")
        self.add_class("objects" , 5 , "reject")
        
        i = 1
        
        # Add images
        # Generate random specifications of images (i.e. color and
        # list of shapes sizes and locations). This is more compact than
        # actual images. Images are generated on the fly in load_image().
        for folder in os.listdir(os.path.join(ROOT_DIR , folder_name)):
            for file in os.listdir(os.path.join(ROOT_DIR , folder_name , folder)):
                extension = os.path.splitext(file)[1]
                if extension == ".xml":
                    file = open(os.path.join(ROOT_DIR , folder_name , folder , file))
                    dictionary = xmltodict.parse(file.read())
                    objects = self.image(dict(dictionary))
                    self.add_image("objects" , image_id = i , path = os.path.join(ROOT_DIR , folder_name , folder , dictionary['annotation']['filename']) , width = int(dictionary['annotation']['size']['width']) , height = int(dictionary['annotation']['size']['height']) , depth = int(dictionary['annotation']['size']['depth']) , objects = objects)
                    i = i + 1
    def load_image(self, image_id):
        """Outputs an image from the path of the given image ID.
        Typically this function loads the image from a file
        """
        info = self.image_info[image_id]                         
        path = info['path']
        image = cv2.imread(path)
        return image

    def image_reference(self, image_id):
        """Return the objects data of the image."""
        info = self.image_info[image_id]
        if info["source"] == "objects":
            return info["objects"]
        else:
            super(self.__class__).image_reference(self, image_id)

    def load_mask(self, image_id):
        """Generate instance masks for shapes of the given image ID.
        """
        info = self.image_info[image_id]
        shapes = info['objects']
        count = len(shapes)
        mask = np.zeros([info['height'] , info['width'] , count], dtype = np.uint8)
        for i, (objects , pose , truncated , difficult , dims) in enumerate(info['objects']):
            xmin , ymin , xmax , ymax = dims
            mask[: , : , i:i+1] = cv2.rectangle(mask[: , : , i:i+1].copy() , (xmin, ymin), (xmax, ymax), (255 , 255 , 255) , -1)
        # Handle occlusions
        occlusion = np.logical_not(mask[: , : , -1]).astype(np.uint8)
        for i in range(count-2, -1, -1):
            mask[: , :  , i] = mask[: , :  , i] * occlusion
            occlusion = np.logical_and(occlusion, np.logical_not(mask[: , : , i]))
        # Map class names to class IDs.
        class_ids = np.array([self.class_names.index(s[0]) for s in shapes])
        return mask.astype(np.bool), class_ids.astype(np.int32)

    def objects_values(self, object_data):
        """Outputs specifications of the objects that lies within
        the given image.
        Returns a tuple of five valus:
        * The object name 
        * Object Pose
        * Object Dimensions: A tuple of values that define the shape size
                            and location. Differs per shape type.
        * Object Difficulty
        * Object Truncated or Not
        """
        # Objects
        objects = self.classes(object_data['name'])
        
        # Pose
        pose = object_data['pose']
        
        # Truncated
        truncated = object_data['truncated']
        
        # Difficult
        difficult = object_data['difficult']
        
        # xmin , ymin , xmax , ymax
        xmin = int(object_data['bndbox']['xmin'])
        ymin = int(object_data['bndbox']['ymin'])
        xmax = int(object_data['bndbox']['xmax'])
        ymax = int(object_data['bndbox']['ymax'])
    
        return objects , pose , truncated , difficult ,  (xmin , ymin , xmax , ymax)
    def classes(self , class_name):
        if class_name == "w":
            return "oralcare"
        elif class_name == "orlab":
            return "oralcare"
        elif class_name == "oral":
            return "oralcare"
        elif class_name == "oralb":
            return "oralcare"
        elif class_name == "vicks":
            return "pharmacy"
        elif class_name == "pampers":
            return "pharmacy"
        elif class_name == "whisper":
            return "pharmacy"
        elif class_name == "gillete":
            return "beauty"
        elif class_name == "gillette":
            return "beauty"
        elif class_name == "ambipureVesus":
            return "beauty"
        elif class_name == "ambipur":
            return "beauty"
        elif class_name == "ambipure":
            return "beauty"
        elif class_name == "home":
            return "beauty"
        elif class_name == "ariel":
            return "beauty"
        elif class_name == "olay":
            return "beauty"
        else:
            return class_name

    def image(self, annotation_data):
        """Creates specifications of the image with multiple objects.
        Returns a list of object specifications that can be used to draw the image.
        """
        shapes = []
        boxes = []
        l = 0
        if 'object' in annotation_data['annotation']:
            for i in annotation_data['annotation']['object']:
                if i == "name":
                    l = l + 1
            if l == 0:
                N = len(annotation_data['annotation']['object'])
                for i in range(N):
                    objects , pose , truncated , difficult , dims = self.objects_values(annotation_data['annotation']['object'][i])
                    shapes.append((objects , pose , truncated , difficult , dims))
                    xmin , ymin , xmax , ymax = dims
                    boxes.append([xmin , ymin , xmax , ymax])
            elif l == 1 :
                objects , pose , truncated , difficult , dims = self.objects_values(annotation_data['annotation']['object'])
                shapes.append((objects , pose , truncated , difficult , dims))
                xmin , ymin , xmax , ymax = dims
                boxes.append([xmin , ymin , xmax , ymax])
            # Apply non-max suppression wit 0.3 threshold to avoid
            # objects covering each other
            if l == 0:
                N = len(annotation_data['annotation']['object'])
                keep_ixs = utils.non_max_suppression(np.array(boxes), np.arange(N), 0.3)
                shapes = [s for i, s in enumerate(shapes) if i in keep_ixs]
        else:
            pass
        return shapes

# %%
dataset_train = ShapesDataset()
dataset_train.load_shapes(folder_name = "train/")
dataset_train.prepare()

dataset_test = ShapesDataset()
dataset_test.load_shapes(folder_name = "test/")
dataset_test.prepare()

# %% [markdown]
# ## Next code to check some objects

# %%
classes = []
for i,m in enumerate(dataset_train.image_info):
    info = dataset_train.image_info[i]
    objects = info['objects']
    for j, (objects , pose , truncated , difficult , dims) in enumerate(info['objects']):
        if objects == "None":
            image = dataset_train.load_image(i)
            mask, class_ids = dataset_train.load_mask(i)
            visualize.display_top_masks(image, mask, class_ids, dataset_train.class_names)
            print(info['path'])

# %%
model = modellib.MaskRCNN(mode = "training" , config = config , model_dir = MODEL_DIR)

# %%
init_with = "coco"  # imagenet, coco

if init_with == "imagenet":
    model.load_weights(model.get_imagenet_weights(), by_name = True)
elif init_with == "coco":
    # Load weights trained on MS COCO, but skip layers that
    # are different due to the different number of classes
    model.load_weights(COCO_MODEL_PATH , by_name = True, exclude = ["mrcnn_class_logits" , "mrcnn_bbox_fc" , "mrcnn_bbox" , "mrcnn_mask"])

# %%
model.train(dataset_train , dataset_test , learning_rate = config.LEARNING_RATE , epochs = 5 , layers = 'heads')
# Out:
# Starting at epoch 0. LR=0.001
#
# Checkpoint Path: ../model_saved\objects20181121T1053\mask_rcnn_objects_{epoch:04d}.h5
# Selecting layers to train
# fpn_c5p5               (Conv2D)
# fpn_c4p4               (Conv2D)
# fpn_c3p3               (Conv2D)
# fpn_c2p2               (Conv2D)
# fpn_p5                 (Conv2D)
# fpn_p2                 (Conv2D)
# fpn_p3                 (Conv2D)
# fpn_p4                 (Conv2D)
# In model:  rpn_model
#     rpn_conv_shared        (Conv2D)
#     rpn_class_raw          (Conv2D)
#     rpn_bbox_pred          (Conv2D)
# mrcnn_mask_conv1       (TimeDistributed)
# mrcnn_mask_bn1         (TimeDistributed)
# mrcnn_mask_conv2       (TimeDistributed)
# mrcnn_mask_bn2         (TimeDistributed)
# mrcnn_class_conv1      (TimeDistributed)
# mrcnn_class_bn1        (TimeDistributed)
# mrcnn_mask_conv3       (TimeDistributed)
# mrcnn_mask_bn3         (TimeDistributed)
# mrcnn_class_conv2      (TimeDistributed)
# mrcnn_class_bn2        (TimeDistributed)
# mrcnn_mask_conv4       (TimeDistributed)
# mrcnn_mask_bn4         (TimeDistributed)
# mrcnn_bbox_fc          (TimeDistributed)
# mrcnn_mask_deconv      (TimeDistributed)
# mrcnn_class_logits     (TimeDistributed)
# mrcnn_mask             (TimeDistributed)
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\tensorflow\python\ops\gradients_impl.py:97: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Epoch 1/5
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   1/100 [..............................] - ETA: 20:14 - loss: 3.8444 - rpn_class_loss: 0.0426 - rpn_bbox_loss: 2.3871 - mrcnn_class_loss: 1.4147 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   2/100 [..............................] - ETA: 11:42 - loss: 2.8489 - rpn_class_loss: 0.0862 - rpn_bbox_loss: 1.7275 - mrcnn_class_loss: 1.0353 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   3/100 [..............................] - ETA: 8:48 - loss: 2.2077 - rpn_class_loss: 0.1258 - rpn_bbox_loss: 1.3345 - mrcnn_class_loss: 0.7475 - mrcnn_bbox_loss: 0.0000e+00 - mrcnn_mask_loss: 0.0000e+00
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   4/100 [>.............................] - ETA: 7:19 - loss: 3.4865 - rpn_class_loss: 0.0944 - rpn_bbox_loss: 1.9057 - mrcnn_class_loss: 0.7134 - mrcnn_bbox_loss: 0.5869 - mrcnn_mask_loss: 0.1861
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   5/100 [>.............................] - ETA: 6:26 - loss: 2.9663 - rpn_class_loss: 0.0913 - rpn_bbox_loss: 1.6856 - mrcnn_class_loss: 0.5710 - mrcnn_bbox_loss: 0.4695 - mrcnn_mask_loss: 0.1489
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   6/100 [>.............................] - ETA: 5:52 - loss: 2.9785 - rpn_class_loss: 0.0859 - rpn_bbox_loss: 1.5014 - mrcnn_class_loss: 0.4961 - mrcnn_bbox_loss: 0.6913 - mrcnn_mask_loss: 0.2039
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   7/100 [=>............................] - ETA: 5:28 - loss: 2.7383 - rpn_class_loss: 0.0969 - rpn_bbox_loss: 1.4489 - mrcnn_class_loss: 0.4252 - mrcnn_bbox_loss: 0.5925 - mrcnn_mask_loss: 0.1748
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   8/100 [=>............................] - ETA: 5:08 - loss: 2.5313 - rpn_class_loss: 0.0972 - rpn_bbox_loss: 1.3907 - mrcnn_class_loss: 0.3721 - mrcnn_bbox_loss: 0.5185 - mrcnn_mask_loss: 0.1529
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#   9/100 [=>............................] - ETA: 4:52 - loss: 2.3848 - rpn_class_loss: 0.1027 - rpn_bbox_loss: 1.3545 - mrcnn_class_loss: 0.3307 - mrcnn_bbox_loss: 0.4609 - mrcnn_mask_loss: 0.1359
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  91/100 [==========================>...] - ETA: 19s - loss: 2.0206 - rpn_class_loss: 0.0291 - rpn_bbox_loss: 0.9168 - mrcnn_class_loss: 0.2709 - mrcnn_bbox_loss: 0.4829 - mrcnn_mask_loss: 0.3209
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  92/100 [==========================>...] - ETA: 17s - loss: 2.0173 - rpn_class_loss: 0.0289 - rpn_bbox_loss: 0.9125 - mrcnn_class_loss: 0.2703 - mrcnn_bbox_loss: 0.4845 - mrcnn_mask_loss: 0.3210
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  93/100 [==========================>...] - ETA: 14s - loss: 2.0110 - rpn_class_loss: 0.0286 - rpn_bbox_loss: 0.9105 - mrcnn_class_loss: 0.2695 - mrcnn_bbox_loss: 0.4821 - mrcnn_mask_loss: 0.3201
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  94/100 [===========================>..] - ETA: 12s - loss: 2.0000 - rpn_class_loss: 0.0284 - rpn_bbox_loss: 0.9030 - mrcnn_class_loss: 0.2680 - mrcnn_bbox_loss: 0.4816 - mrcnn_mask_loss: 0.3190
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  95/100 [===========================>..] - ETA: 10s - loss: 2.0061 - rpn_class_loss: 0.0285 - rpn_bbox_loss: 0.9029 - mrcnn_class_loss: 0.2739 - mrcnn_bbox_loss: 0.4815 - mrcnn_mask_loss: 0.3194
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  96/100 [===========================>..] - ETA: 8s - loss: 2.0090 - rpn_class_loss: 0.0285 - rpn_bbox_loss: 0.9009 - mrcnn_class_loss: 0.2779 - mrcnn_bbox_loss: 0.4815 - mrcnn_mask_loss: 0.3202
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  97/100 [============================>.] - ETA: 6s - loss: 2.0158 - rpn_class_loss: 0.0296 - rpn_bbox_loss: 0.8995 - mrcnn_class_loss: 0.2816 - mrcnn_bbox_loss: 0.4828 - mrcnn_mask_loss: 0.3223
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  98/100 [============================>.] - ETA: 4s - loss: 2.0159 - rpn_class_loss: 0.0296 - rpn_bbox_loss: 0.8975 - mrcnn_class_loss: 0.2791 - mrcnn_bbox_loss: 0.4858 - mrcnn_mask_loss: 0.3239
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
#  99/100 [============================>.] - ETA: 2s - loss: 2.0179 - rpn_class_loss: 0.0297 - rpn_bbox_loss: 0.8948 - mrcnn_class_loss: 0.2802 - mrcnn_bbox_loss: 0.4873 - mrcnn_mask_loss: 0.3258
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# 100/100 [==============================] - 224s 2s/step - loss: 2.0097 - rpn_class_loss: 0.0295 - rpn_bbox_loss: 0.8978 - mrcnn_class_loss: 0.2774 - mrcnn_bbox_loss: 0.4825 - mrcnn_mask_loss: 0.3225 - val_loss: 1.6913 - val_rpn_class_loss: 0.0150 - val_rpn_bbox_loss: 0.7197 - val_mrcnn_class_loss: 0.3823 - val_mrcnn_bbox_loss: 0.3271 - val_mrcnn_mask_loss: 0.2472

# %% [markdown]
# # Running model on test data set

# %%
class InferenceConfig(ShapesConfig):
    GPU_COUNT = 1
    IMAGES_PER_GPU = 1

inference_config = InferenceConfig(num_classes = 6)

# Recreate the model in inference mode
model = modellib.MaskRCNN(mode = "inference", 
                          config = inference_config,
                          model_dir = MODEL_DIR)

# Get path to saved weights
model_path = "../model_saved/objects20181121T1053/mask_rcnn_objects_0005.h5"

# Load trained weights
print("Loading weights from ", model_path)
model.load_weights(model_path, by_name = True)
# Out:
# Loading weights from  ../model_saved/objects20181121T1053/mask_rcnn_objects_0005.h5
# Re-starting from epoch 5

# %%
image_id = random.choice(dataset_test.image_ids)
original_image, image_meta, gt_class_id, gt_bbox, gt_mask =\
    modellib.load_image_gt(dataset_test, inference_config, 
                           image_id, use_mini_mask = False)

log("original_image", original_image)
log("image_meta", image_meta)
log("gt_class_id", gt_class_id)
log("gt_bbox", gt_bbox)
log("gt_mask", gt_mask)

visualize.display_instances(original_image, gt_bbox, gt_mask, gt_class_id, 
                            dataset_train.class_names, figsize = (8, 8))
# Out:
# original_image           shape: (768, 768, 3)         min:    0.00000  max:  255.00000  uint8
# image_meta               shape: (18,)                 min:    0.00000  max:  970.00000  float64
# gt_class_id              shape: (3,)                  min:    2.00000  max:    2.00000  int32
# gt_bbox                  shape: (3, 4)                min:  181.00000  max:  629.00000  int32
# gt_mask                  shape: (768, 768, 3)         min:    0.00000  max:    1.00000  bool

# %%
results = model.detect([original_image], verbose = 1)

r = results[0]
visualize.display_instances(original_image, r['rois'], r['masks'], r['class_ids'], 
                            dataset_test.class_names, r['scores'], ax = get_ax())
# Out:
# Processing 1 images
# image                    shape: (768, 768, 3)         min:    0.00000  max:  255.00000  uint8
# molded_images            shape: (1, 768, 768, 3)      min: -123.70000  max:  151.10000  float64
# image_metas              shape: (1, 18)               min:    0.00000  max:  768.00000  int32
# anchors                  shape: (1, 147312, 4)        min:   -0.11800  max:    1.03456  float32
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "

# %% [markdown]
# # Accuracy

# %%
image_ids = np.random.choice(dataset_test.image_ids , 10)
APs = []
for image_id in image_ids:
    # Load image and ground truth data
    image, image_meta, gt_class_id, gt_bbox, gt_mask =\
        modellib.load_image_gt(dataset_test, inference_config,
                               image_id, use_mini_mask = False)
    molded_images = np.expand_dims(modellib.mold_image(image, inference_config), 0)
    # Run object detection
    results = model.detect([image], verbose=0)
    r = results[0]
    # Compute AP
    AP, precisions, recalls, overlaps =\
        utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
                         r["rois"], r["class_ids"], r["scores"], r['masks'])
    APs.append(AP)
    
print("mAP: ", np.mean(APs))
# Out:
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\skimage\transform\_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-3c5b3042af39> in <module>
#      13     AP, precisions, recalls, overlaps =\
#      14         utils.compute_ap(gt_bbox, gt_class_id, gt_mask,
# ---> 15                          r["rois"], r["class_ids"], r["scores"], r['masks'])
#      16     APs.append(AP)
#      17
#
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\mrcnn\utils.py in compute_ap(gt_boxes, gt_class_ids, gt_masks, pred_boxes, pred_class_ids, pred_scores, pred_masks, iou_threshold)
#     737         gt_boxes, gt_class_ids, gt_masks,
#     738         pred_boxes, pred_class_ids, pred_scores, pred_masks,
# --> 739         iou_threshold)
#     740
#     741     # Compute precision and recall at each prediction box step
#
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\mrcnn\utils.py in compute_matches(gt_boxes, gt_class_ids, gt_masks, pred_boxes, pred_class_ids, pred_scores, pred_masks, iou_threshold, score_threshold)
#     689
#     690     # Compute IoU overlaps [pred_masks, gt_masks]
# --> 691     overlaps = compute_overlaps_masks(pred_masks, gt_masks)
#     692
#     693     # Loop through predictions and find matching ground truth boxes
#
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\mrcnn\utils.py in compute_overlaps_masks(masks1, masks2)
#     105         return np.zeros((masks1.shape[0], masks2.shape[-1]))
#     106     # flatten masks and compute their areas
# --> 107     masks1 = np.reshape(masks1 > .5, (-1, masks1.shape[-1])).astype(np.float32)
#     108     masks2 = np.reshape(masks2 > .5, (-1, masks2.shape[-1])).astype(np.float32)
#     109     area1 = np.sum(masks1, axis=0)
#
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\numpy\core\fromnumeric.py in reshape(a, newshape, order)
#     277            [5, 6]])
#     278     """
# --> 279     return _wrapfunc(a, 'reshape', newshape, order=order)
#     280
#     281
#
# c:\users\nbans\appdata\local\programs\python\python36\lib\site-packages\numpy\core\fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      49 def _wrapfunc(obj, method, *args, **kwds):
#      50     try:
# ---> 51         return getattr(obj, method)(*args, **kwds)
#      52
#      53     # An AttributeError occurs if the object does not have
#
# ValueError: cannot reshape array of size 0 into shape (0)
